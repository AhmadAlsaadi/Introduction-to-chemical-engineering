# %% [markdown]
#  # <center> Chapter 6: Material Balances for Multi-Unit Systems

# %% [markdown]
# ## Objectives:

# %% [markdown]
# 1. Write a set of independent material balances for a process involving more than one unit.

# %% [markdown]
# 2. Solve problems by hand in which a small number of interconnected units are involved
# by making appropriate balances.

# %% [markdown]
# 3. Use the overall conversion and single-pass (once-through) conversion concepts in
# solving recycle problems involving reactors.

# %% [markdown]
# 4. Explain the purpose of a recycle stream, a bypass stream, and a purge stream.

# %% [markdown]
# 5. Understand in a general sense how material balances are used in industry.

# %% [markdown]
# ## 6.1 Primary Concepts

# %% [markdown]
# - **A process flowsheet (flowchart)** is a graphical representation of a process.  it describes
# the actual process in sufficient detail that you can use it to formulate material (and energy) balances, for troubleshooting, control of operating conditions, and optimization of process performance.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# <center>Flowsheet of the ammonia plant

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <center>Block diagram of the ammonia plant

# %% [markdown]
# - **purge**:removing a small portion of a material to prevent its accumulation in the process

# %% [markdown]
# - The streams entering or leaving a splitter has the same composition, only one independent material balance equation can be written for a splitter.

# %% [markdown]
# - For most problems involving multi-units, the number of pertinent independent material
# balance equations that can be written is considerably lower than the total number of material balance
# equations that could be written.

# %% [markdown]
# - If you are going to solve multi-unit problems by hand, you have to carefully choose the order in which you solve the various equations to avoid having to solve too many equations simultaneously.

# %% [markdown]
# ## 6.2 Sequential Multi-Unit Systems

# %% [markdown]
# ![image.png](attachment:image.png)
# <br>
# <center> Mixing and splitting in a process without reaction

# %% [markdown]
# - How many material balances can you formulate for the system and subsystems shown above?

# %% [markdown]
# ![image.png](attachment:image.png)
# <br>
#
# <center> boundary for an overall total material balance

# %% [markdown]
# ![image.png](attachment:image.png)
# <br>
# <center>boundary for the material balances around each individual process

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# How many independent material balance equations can be written for the
# process illustrated above with three components?

# %% [markdown]
# - Start with subsystem that has zero degree of freedom.
# - Sometime the best way is to start with the overall material balance.

# %% [markdown]
# **Example 6.1** Lactic acid ($C_3H_6O_3$) produced by fermentation is used in the food, chemical, and pharmaceutical industries. The figure below illustrates the mixing of components to form a suitable fermentation broth. The whole system is steady-state and open. The arrows designate the direction of the flows. No reaction occurs in any of the subsystems.
# ![image.png](attachment:image.png)
# The mass compositions of each stream are as follows:
# 1. Water (W): 100%
# 2. Glucose (G): 100%
# 3. W and G, concentrations known: ωW = 0.800 and ωG = 0.200
# 4. Lactobacillus (L): 100%
# 5. W, G, and L, concentrations known: ωW = 0.769, ωG = 0.192, ωL = 0.0385
# 6. Vitamin G with amino acids and phosphate (V): 100%
# 7. ωW = 0.962, ωV = 0.0385
# 8. ωG = 0.833, ωL = 0.167
# What is the maximum number of independent mass balances that can be generated for this system?

# %% [markdown]
# **Solution**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Subsystem I:
# ![image.png](attachment:image.png)

# %% [markdown]
# Subsystem II:
# ![image.png](attachment:image.png)

# %% [markdown]
# Subsystem III:
# ![image.png](attachment:image.png)

# %% [markdown]
# If you take as an arbitrary basis $F_1$ = 100, seven values of $F_i$ are unknown; hence only seven
# independent equations need to be written.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Frequently Asked Questions**

# %% [markdown]
# 1. In carrying out a degree-of-freedom analysis, do you have to include at the start of the analysis
# every one of the variables and equations that are involved in the entire process?
#
# No. What you
# do is to pick a system for analysis, and you only have to take into account the unknowns and
# equations pertaining to the streams cut by the system boundary (plus components inside the system if it is an unsteady-state system).

# %% [markdown]
# 2. Should you use element material balances or species material balances in solving problems that
# involve multiple units?
#
# For processes that do not involve reaction, use species balances; element balances are quite inefficient. For processes that do involve reaction, if you are given
# the reactions and information that enable you to calculate the extent of reaction, use species
# balances. Even if you are not specifically given the reactions, you can often formulate them
# based on your experience, such as C burning with $O_2$ to yield $CO_2$. But if such data are missing,
# element balances are easier to use. Just make sure that they are independent!

# %% [markdown]
# **Example 6.2.1**: Acetone is used in the manufacture of many chemicals and also as a solvent. In its latter role, many restrictions are placed on the release of acetone vapor to the environment. You are asked to design an acetone recovery system having the flowsheet illustrated in figure below. All of the concentrations shown in the figure of both the gases and liquids are specified in weight percent
# in this special case to make the calculations simpler. Calculate A, F, W, B, and D in kilograms per
# hour. Assume that G = 1400 kg/hr.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Solution**

# %% [markdown]
# Basis: 1 hour.

# %% [markdown]
# Unit 1 (absorber):

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Units 2 and 3 (distillation column plus condenser):

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Example 6.2.2**: In the face of higher fuel costs and the uncertainty of the supply of a particular fuel, many companies operate two furnaces, one fired with natural gas and the other with fuel oil. In the RAMAD Corp., each furnace has its own supply of oxygen; the oil furnace uses as a source of
# oxygen a stream that has the following composition: $O_2$ 20%, $N_2$ 76%, and $CO_2$ 4%. The stack
# gases from both furnaces exit using a common stack.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Note that two outputs are shown in the common stack to point out that the stack gas analysis is on a
# dry basis but water vapor also exists. The fuel oil composition is given in mole fractions to save
# you the bother of converting mass fractions to mole fractions.

# %% [markdown]
# During one blizzard, all transportation to the RAMAD Corp. was cut off, and officials were
# worried about the dwindling reserves of fuel oil because the natural-gas supply was being used at
# its maximum rate possible. The reserve of fuel oil was only 560 bbl. How many hours could the company operate before shutting down if no additional fuel oil was attainable? How many pound
# moles per hour of natural gas were being consumed? The minimum heating load for the company
# when translated into the stack gas output was 6205 lb mol/hr of dry stack gas. Analysis of the fuels
# and stack gas at this time is shown in the figure above. The molecular weight of the fuel oil was 7.91 lb/lb mol, and its density was 7.578 lb/gal.

# %% [markdown]
# **Solution**:

# %% [markdown]
# Basis: 1 hr, so that P = 6205 lb mol

# %% [markdown]
# Element material balance:

# %% [markdown]
#  | Component| Material Balance Equation |
#  |:--------:|:-------------------------|
#  |   H      |0A +             0A* + (0.47)(2)F +             ((0.02)(2)+(0.96)(4))G -   2W = 0      |
#  |   N      |(0.79)(2)A +     (0.76)(2)A* +         0F +              0G +   0W = (6205)(0.8493)(2) |
#  |   O      |(0.21)(2)A + (0.2+0.04)(2)A* + 0F + (0.02)(2)G -  W = (6205)  (0.0413+0.001+0.1084)(2)|
#  |   S      |       0A +             0A* +    (0.03)F +                   0G +   0W = (6205)(0.0010)|
#  |   C      |       0A +        0.04A* +      0.50F + (0.96+(2)(0.02)+0.02)G +   0W = (6205)(0.1084)|

# %%
#################################################################################################
#         A               A*            F                         G      W   
#        0A +             0A* + (0.47)(2)F +             ((0.02)(2)+(0.96)(4))G -   2W = 0
#(0.79)(2)A +     (0.76)(2)A* +         0F +                     0G +   0W = (6205)(0.8493)(2)
#(0.21)(2)A + (0.2+0.04)(2)A* +         0F +             (0.02)(2)G -    W = (6205)(0.0413+0.001+0.1084)(2)
#        0A +             0A* +    (0.03)F +                     0G +   0W = (6205)(0.0010)
#        0A +          0.04A* +      0.50F + (0.96+(2)(0.02)+0.02)G +   0W = (6205)(0.1084)
#################################################################################################

import numpy as np

A=np.array([[    0,          0, 0.47*2,   (0.02*2 +0.96*4), -2],
            [.79*2,     0.76*2,      0,                  0,  0],
            [.21*2, 2*(.2+.04),      0,             0.02*2, -1],
            [    0,          0,   0.03,                  0,  0],
            [    0,       0.04,   0.50, (0.96+2*0.02+0.02),  0]])

B=np.array([0, (6205*.8493*2), (6205)*(0.0413+.001+0.1084)*2, 6205*0.001, 6205*0.1084 ])

answer=np.linalg.inv(A).dot(B)
print('A  = ',answer[0])
print('A* = ',answer[1])
print('F  = ',answer[2])
print('G  = ',answer[3])
print('W  = ',answer[4])
# Out:
# A  =  5225.991163532388
# A* =  1501.8072115913383
# F  =  206.83333333333377
# G  =  499.1500439898822
# W  =  1065.5627520070384

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Example 6.2.3**: The figure below shows the process and the known data. You are asked to calculate the compositions of every flow stream, and the fraction of the sugar in the cane (F) that is recovered in M.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Solution**:

# %% [markdown]
# **General rule**,
# >The basis you choose and the unit with which you start
# the analysis in a multi-unit process affect the degree of complexity of your calculations.

# %% [markdown]
# Basis: 1 hr (M = 1000 lb)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For the crystallizer:
#
# Sugar: $$ K (0.40) = L (0) + 1000$$
# Water: $$K (0.60) = L + 0$$

# %% [markdown]
# $$K = 2500\text{ lb}$$
# $$L = 1500\text{ lb}$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The percent sugar recovered
# $$\frac{1000}{(24,574) (0.16)} = 0.25$$

# %% [markdown]
# ## 6.3 Recycle Systems

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **<center> water cycle </center>**

# %% [markdown]
# - Recycle of unused reactants to the reactor can offer significant economic savings for high volume processing systems.

# %% [markdown]
# - Heat recovery within a processing unit (comprising energy recycle) reduces the overall energy consumption of the process.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# **<center>Possible system boundaries for the material balances</center>**

# %% [markdown]
# - The main new aspect of solving problems involving recycle is picking the proper sequence of
# systems to analyze.

# %% [markdown]
# - Recycle problems lead to coupled equations that have to be solved simultaneously.

# %% [markdown]
# - You will find that overall material balances (1 in the Figure above), particularly with a tie component, are usually a good place to start when solving recycle problems.

# %% [markdown]
# **Frequently Asked Question**

# %% [markdown]
# - If you feed material to a stream continuously as in Figure 6.4c, why does the value of the material in the recycle stream not increase and continue to build up?

# %% [markdown]
#  We assume, often without so stating, that the entire process including all units is in the
# steady state. As the process starts up or shuts down, the flows in many of the streams change, but
# once the steady state is reached, “what goes in must come out” applies to the recycle stream as well
# as the other streams in the process.

# %% [markdown]
# ### 6.3.1 Recycle without Reaction

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <br>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Example 6.3.1.1** The figure below is a schematic of a process for the production of biomass (denoted as Bio) that is to be used in the production of drugs.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The fresh feed F to the process is 10,000 lb/hr of a 40 wt % aqueous biomass in suspension. The
# fresh feed is combined with the recycled filtrate from the filter and fed to the evaporator, where
# water is removed to produce a 50 wt % Bio solution, which is fed to the filter. The filter produces
# a filter cake that is composed of 95 wt % dry biomass wet by a 5 wt % solution that in the lab
# proves to be composed of 55 wt % water with the rest dry biomass. The filtrate contains 45 wt %
# biomass.
#
# a. Determine the flow rate of water removed by the evaporator and the recycle rate for this
# process.
#
# b. Assume that the same production rate of filter cake occurs, but that the filtrate is not
# recycled. What would be the process feed rate of 40 wt % biomass then? Assume that the
# product solution from the evaporator still contains 50 wt % biomass in water.

# %% [markdown]
# **Solution**
#
# a.

# %% [markdown]
# Basis: 10,000 lb fresh feed (equivalent to 1 hr)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Bio balance on the filter:
# $$0.5G = 4000 + 0.45R$$

# %% [markdown]
# $H_2O$ balance on the filter:
# $$0.5G = 113 + 0.55R$$

# %% [markdown]
# $$R = 870\text{ lb in 1 hr}$$
#
# $$G = 4983\text{ lb in 1 hr}$$

# %% [markdown]
# b.

# %% [markdown]
# The basis is now P = 4113 lb (the same as 1 hr).

# %% [markdown]
# Bio balance on the filter:
# $$0.5G = [(0.95) + (0.05)(0.45)](4113) + 0.45R$$

# %% [markdown]
# $H_2O$ balance on the filter:
# $$0.5G = [(0.05)(0.55)](4113) + 0.55R$$

# %% [markdown]
# Solve simultaneously:
# $$R = 38,870\text{ lb in 1 hr}$$

# %% [markdown]
# - Note that without recycle, the feed rate must be 5.37 times larger to produce the same amount of
# product, not to mention the fact that you would have to dispose of a large volume of filtrate, which
# is 45 wt % Bio.

# %% [markdown]
# ### 6.3.2 Recycle with Chemical Reaction

# %% [markdown]
# - The most common application of recycle for systems involving chemical reaction is the recycle of
# reactants, an application that is used to increase the overall conversion in a reactor.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Two different types of conversions that can be applied to processes in which reaction occurs:

# %% [markdown]
# - Overall conversion is based on what enters and leaves the overall process:

# %% [markdown]
# $$\text{Overall conversion}=f_{OA}=\frac{\text{moles of limiting reactant in the fresh feed}          -\text{moles of limiting reactant in the out of the overall process}}{\text{moles of limiting reactant in the fresh feed}}$$

# %% [markdown]
# - The single-pass conversion is based on what enters and leaves the reactor:

# %% [markdown]
# $$\text{Single-pass conversion}=f_{SP}=$$
# ![image.png](attachment:image.png)

# %% [markdown]
# For the figure above:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Conversion in a reactor (the single-pass conversion) can be limited by chemical equilibrium and/or chemical kinetics.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - On the other hand, the overall conversion is strongly dependent upon the efficiency of the separator in separating compounds to be recycled from the other compounds.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - The extent of reaction is the same regardless of whether an overall material balance is used or a material balance for the reactor is used.

# %% [markdown]
# **Example 6.3.2.1**

# %% [markdown]
# Cyclohexane ($C_6H_{12}$) can be made by the reaction of benzene (Bz, short for $C_6H_{6}$) with hydrogen according to the following reaction:
# $$C_6H_6 + 3H_2 → C_6H_{12}$$
# For the process shown in the figure below, determine the ratio of the recycle stream to the fresh feed stream if the overall conversion of benzene is 95% and the single-pass conversion through the
# reactor is 20%. Assume that 20% excess hydrogen is used in the fresh feed, and that the
# composition of the recycle stream is 22.74 mol % benzene and 78.26 mol % hydrogen.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Note that in this example, there is a relatively low conversion per pass (20%) and the overall
# conversion is relatively high (95%). A low conversion per pass can be desirable in certain cases,
# for example, a case in which the yield decreases as the conversion increases. By using recycle, you
# can obtain a high yield and at the same time a high overall conversion (i.e., high utilization of the
# limiting reactant)

# %% [markdown]
# **Solution**

# %% [markdown]
# Basis: 100 mole of benzene.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$\text{total fresh feed} = 460\text{ mol}$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$ξ = 95 $$

# %% [markdown]
# Overall balances:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Calculating R:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# $$R = 1649\text{ mol}$$

# %% [markdown]
# The ratio of recycle to fresh feed:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Example 6.3.2.2**

# %% [markdown]
# Immobilized glucose isomerase is used as a catalyst in producing fructose from glucose in a fixed bed reactor (water is the solvent). For the system shown in the figure below, what percent conversion
# of glucose results on one pass through the reactor when the ratio of the exit stream to the recycle
# stream in mass units is equal to 8.33? The reaction is

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Solution**

# %% [markdown]
# Basis S = 100 kg given the data shown in the figure below:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Overall balances:
#
# $$P = 100 kg$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For water:
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
