# %% [markdown]
# # Chapter 5: Material Balance with Chemical Reaction

# %% [markdown]
# **Chapter Objectives**:
#
# *  Write and balance chemical reaction equations
# *  Determine the stoichiometric quantities of reactants and products in moles   or mass given the chemical reaction.
# *  Identify the limiting and excess reactants in a reaction.
# *  Calculate :
#     - The fraction or percent excess reactant(s).
#     - The percent conversion, or completion.
#     - The yield.
#     - The extent of reaction for a chemical reaction with the reactants given in nonstoichiometric proportion.
# *  Carry out a degree-of-freedom analysis for processes involving chemical reaction(s).
# *  Formulate and solve material balances using (a) species balances and (b) element balances.
# *  Decide when element balances can be used as material balances.
# *  Understand how the extent of reaction is determined for a process, and how to apply it in material balance problems.
# *  Understand the meaning of:
#     - Stack gas for flue gas.
#     - Orsat analysis.
#     - Dry basis.
#     - Wet basis,
#     - Theoretical air (oxygen).
#     - Excess air (oxygen).

# %% [markdown]
# ## 5.1 Stoichiometry
#
# * The heart of many plants is the reactor in which products and by-products are produced.

# %% [markdown]
# * Material balances considering reactions are used to design reactors.

# %% [markdown]
# * Chemical engineers differ from most other engineers because of their application of chemistry.

# %% [markdown]
# * The word stoichiometry (stoi-ki-OM-e-tri) derives from two Greek words:
#     * stoicheion (meaning “element”)
#     * metron (meaning “measure”).

# %% [markdown]
# * Chemical reactions differs from physical changes (evaporation or dissolution):
#     *  You want to be able to predict the mass or moles required for the reaction(s).
#
#     *  You want to know the mass or moles of each species remaining after the reaction has occurred.

# %% [markdown]
# * Stoichiometry provides a quantitative means of relating the amount of products produced by a chemical reaction(s) to the amount of reactants or vice versa.

# %% [markdown]
# * Chemical reaction equation provides both qualitative and quantitative information concerning chemical reactions that occur in a chemical process.

# %% [markdown]
# * *The law of constant proportionality*, which states that chemical reactions proceed with fixed ratios of the number of reactants and products involved in the reaction.

# %% [markdown]
# * Steps for solving problems involving stoichiometry  :
#     * Make sure the chemical equation is correctly balanced.
#
#     $$CH_4 +2O_2\rightarrow CO_2+2H_2O$$
#
#     * Use the proper degree of completion for the reaction. If you do not know how much of the reaction has occurred, you may assume a reactant reacts completely.
#     * Use molecular weights to convert mass to moles for the reactants and moles to mass for the products.
#     * Use the coefficients in the chemical equation to obtain the relative molar amounts of products produced and reactants consumed in the reaction.

# %% [markdown]
# **Example 5.1.1**:
#
# $$C_7H_{16}(l) + 11 O_2(g) \rightarrow 7 CO_2(g) + 8 H_2O(g)$$

# %% [markdown]
# What can you learn from this equation?

# %% [markdown]
# How many kilograms of $CO_2$ will be produced as product if 10 kg of $C_7H_{16}$ react completely with the stoichiometric quantity of $O_2$?

# %% [markdown]
# **Solution**:

# %% [markdown]
# convert mass of $C_7H_{16}$ into moles using its molecular weight:

# %% [markdown]
# $$10 \text{ kg } C_7H_{16}\frac{1 \text{ kg mole } C_7H_{16}}{100.1 \text{ kg } C_7H_{16}}=0.1\text{ kg mole }C_7H_{16}$$

# %% [markdown]
# Use the balanced reaction equation to calculate moles of $CO_2$ produced:

# %% [markdown]
# $$0.1\text{ kg mole of }C_7H_{16} \frac{\text{7 kg mole of }CO_2}{\text{1 kg mole }C_7H_{16}}=0.7\text{ kg mole }CO_2$$

# %% [markdown]
# convert $CO_2$ moles to kg moles:

# %% [markdown]
# $$0.7\text{ kg mole }CO_2\frac{44.0 \text{ kg }CO_2}{1\text{ kg mole }CO_2}=30.8\text{ kg } CO_2$$

# %% [markdown]
# General chemical reaction equation:

# %% [markdown]
# $$cC + dD \rightleftharpoons aA + bB$$

# %% [markdown]
# $$v_AA + v_BB + v_CC + v_DD=\sum{v_iS_i}=0$$

# %% [markdown]
# $v_i$: stoichiometric coefficient for species $S_i$
#
# $v_C=-c$
#
# $v_D=-d$
#
# $v_B=b$
#
# $v_A=a$

# %% [markdown]
# **Example 5.1.2**: The primary energy source for cells is the aerobic catabolism (oxidation) of glucose ($C_6H_{12}O_6$, a sugar). The overall oxidation of glucose produces $CO_2$ and $H_2O$ by the following reaction:
#
# $$C_6H_{12}O_6 + a O_2 → b CO_2 + c H_2O$$
#
# Balance the equation?

# %% [markdown]
# **Solution**
#
# Carbon balance: $b=6$
#
# Hydrogen balance: $c=6$
#
# Oxygen balance:$6+2a=6x2+6$ ==> a=6

# %% [markdown]
# $$C_6H_{12}O_6 + 6 O_2 → 6 CO_2 + 6 H_2O$$

# %% [markdown]
# **EXample 5.1.3**: In the combustion of heptane with oxygen, $CO_2$ is produced. Assume that you want to produce 500 kg of dry ice per hour, and that 50% of the CO2 can be converted into dry ice, as shown in Figure
# below. How many kilograms of heptane must be burned per hour?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Solution**:
#
# bases: 1 hr.
#
# The chemical equation:
#
# $$C_7H_{16} + 11 O_2 → 7 CO_2 + 8 H_2O$$

# %% [markdown]
# kg of co2 that resulted from the reaction: 500kg/0.5=1000 kg co2
#
#
# 1000/44.o = 22.73 kg mole
#
# 22.73/7  =3.25 kgmoel hepane
#
# 3.25 kgmole x MW =3.25*100.1 = 325 kg of heptane

# %%
3.25*100.1
# Out:
# 325.325

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Example 5.1.4**: A limestone analysis:
# - $CaCO_3$   = 92.89%
# - $MgCO_3$   = 5.41%
# - Unreactive = 1.70%
#
# By heating the limestone, you recover oxides that together are known as lime.
#
#   a. How many pounds of calcium oxide can be made from 1 ton of this limestone?
#
#   b. How many pounds of $CO_2$ can be recovered per pound of limestone?
#
#   c. How many pounds of limestone are needed to make 1 ton of lime?

# %% [markdown]
# **Solution**:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Chemical reaction equations:
#
# $$CaCO_3 → CaO + CO_2$$
#
# $$MgCO_3 → MgO + CO_2$$

# %% [markdown]
# Molecular weights of compounds:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Basis: 100 lb of limestone

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# From the reaction equations:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# production of $CO_2$:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# a.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# b.

# %% [markdown]
# $$CO_2\text{ recovered}=\frac{44.67\text{ lb }CO_2}{100 \text{ lb limestone}}=0.447\text{ lb } CO_2$$

# %% [markdown]
# c.

# %% [markdown]
# $$\text{Limestone required}=\frac{100\text{ lb stone}}{54.63\text{ lb lime}}\frac{2000 \text{ lb lime}}{1 \text{ ton lime}}=3661 \text{ lb stone}$$

# %% [markdown]
# ## 5.2 Terminology for Reaction Systems

# %% [markdown]
# * What if improper stoichiometric ratio reactants is fed into a reactor?
# * What if the reaction is incomplete?

# %% [markdown]
# ### 5.2.1 Extent of Reaction, $\zeta$

# %% [markdown]
# * The extent of reaction applies to each species in the reaction.

# %% [markdown]
# * The extent of reaction, ξ, is based on a specified stoichiometric equation and denotes how much reaction occurs.

# %% [markdown]
# * The extent of reaction is calculated by dividing the change in the number of moles of a species that occurs in a reaction, for either a reactant or a product, by the associated stoichiometric coefficient (which has the units of the change in the moles of species i divided by the moles reacting).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - $n_i$ = moles of species i present in the system after the reaction occurs.
#
#
# - $n_{io}$ = moles of species i present in the system when the reaction starts.
#
#
# - $ν_i$ = stoichiometric coefficient for species i in the specified chemical reaction equation (moles of species per moles reacting).
#
#
# - ξ = extent of reaction (moles reacting according to the assumed reaction stoichiometry)

# %% [markdown]
# rearrange equation terms:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Example 5.2.1**:
#
# $$2 CO + O_2 → 2 CO_2$$

# %% [markdown]
# If 20 moles of CO are combined with 10 moles of $O_2$ to form 15 moles of $CO_2$, What is the extent of this reaction?

# %% [markdown]
# **Solution**:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Example 5.1.2** NADH (nicotinamid adenine dinucleotide) supplies hydrogen in living cells for biosynthesis reactions such as
#
# $$CO_2 + 4H → CH_2O + H_2O$$
#
# If you saturate 1 L of deaerated water with $CO_2$ gas at $20^oC$ (the solubility is 1.81 g $CO_2/L$) and add enough NADH to provide 0.057 g of H into a bioreactor used to imitate the reactions in cells, and obtain 0.7 g of $CH_2O$, what is the extent of reaction for this reaction? Use the extent of reaction to determine the number of grams of $CO_2$ left in solution.

# %% [markdown]
# **Solution**
#
# Basis: 1 L of water saturated with $CO_2$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The extent of reaction:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# $CO_2$ left in solution:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5.2.2 Limiting and Excess Reactants

# %% [markdown]
# - The **limiting reactant** is defined as the species in a chemical reaction that
# theoretically would be the first to be completely consumed if the reaction were to proceed to completion according to the chemical equation (even if the reaction does not proceed to completion!).

# %% [markdown]
# - All of the other reactants are called **excess reactants**.

# %% [markdown]
# **Example 5.2.2.1**
#
# $$C_7H_{16} + 11O_2 → 7CO_2 + 8H_2O$$

# %% [markdown]
# - 1 gmol of $C7H_{16}$ + 12 gmol $O_2$

# %% [markdown]
# **Solution**
#
# The reactant with the smallest maximum extent of reaction is the limiting reactant:
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Therefore, heptane ($C_7H_{16}$) is the limiting reactant and oxygen is the excess reactant.

# %% [markdown]
# **Example 5.2.2.2** For the same data as in **Example 5.1.2** The basis is the same and the figure is
# the same.
#
# a. What is the maximum number of grams of $CH_2O$ that can be produced?
#
# b. What is the limiting reactant?
#
# c. What is the excess reactant?

# %% [markdown]
# **Solution**
#
# - The reactant with the smallest maximum extent of reaction is the limiting reactant:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - (b) H is the limiting reactant
# - (c) $CO_2$ is the excess reactant.
# - (a)
#
#
# $$0.057\text{ gmol H}\frac{1 \text{ gmol }CH_2O}{4\text{ gmol } H}\frac{30.02\text{ g }CH_2O}{1\text{ g mol }CH_2O}=0.478 g CH_2O$$

# %% [markdown]
# ### 5.2.3 Conversion and Degree of Completion

# %% [markdown]
# - Conversion (or the degree of completion) is the fraction of the limiting reactant in the feed that is converted into products.
# - Conversion is dimensionless.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Example 5.2.3.1**  if 14.4 kg of $CO_2$ are formed in the reaction of 10 kg of $C_7H_{16}$, calculate the percent of the $C_7H_{16}$ that is converted to $CO_2$?
#
# $$C_7H_{16} + 11O_2 → 7CO_2 + 8H_2O$$

# %% [markdown]
# **Solution**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Alternative solution**:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5.2.4 Selectivity

# %% [markdown]
# - **Selectivity** is the ratio of the *moles* of a particular (usually the desired) product produced to the
# moles of another (usually undesired or by-product) product produced in a single reaction or group of
# reactions.

# %% [markdown]
# $$2 CH_3OH → C_2H_4 + 2H_2O$$
#
# $$3 CH_3OH → C_3H_6 + 3H_2O$$

# %% [markdown]
# What is the selectivity of $C_2H_4$ relative to the $C_3H_6$ at 80% conversion of the $CH_3OH$?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Proceed upward at 80% conversion to get:
#     - $C_2H_4$ ≅ 19 mol %
#     - $C_3H_6$ ≅ 8 mol %.
#
# $$Conversion = \frac{19}{8}=2.4 $$

# %% [markdown]
# ### 5.2.5 Yield

# %% [markdown]
# - No universally agreed-upon definitions exist for yield.
#
#     -  **Yield** (*based on feed*): The amount (mass or moles) of desired product obtained divided by the amount of the key (frequently the limiting) reactant fed.
#
#     - **Yield** (*based on reactant consumed*): The amount (mass or moles) of desired product obtained divided by the amount of the key (frequently the limiting) reactant consumed.
#
#     - **Yield** (*based on 100% conversion*): The amount (mass or moles) of a product obtained divided by the theoretical (expected) amount of the product that would be obtained based on the limiting reactant in the chemical reaction equation(s) if it were completely consumed.

# %% [markdown]
# - The actual yield in a reaction does not equal the theoretical yield predicted from the chemical reaction equation for the following reasons:
#     -  Impurities among the reactants.
#     -  Leaks to the environment.
#     -  Side reactions.
#     -  Reversible reactions.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - The terms **yield** and **selectivity** are terms that measure the degree to which a desired reaction proceeds relative to competing alternative (undesirable) reactions.

# %% [markdown]
# - As a designer of equipment, you want to maximize production of the desired product and minimize production of the unwanted products.

# %% [markdown]
# **Example 5.5.1** Semenov [N. N. Semenov, Some Problems in Chemical Kinetics and Reactivity, Vol. II, Princeton University Press, Princeton (1959), pp. 39–42] described some of the chemistry of alkyl chlorides. The two reactions of interest for this example are:
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $C_3H_6$ is propene (MW = 42.08).
#
#
# $C_3H_5Cl$ is allyl chloride (3-chloropropene) (MW = 76.53).
#
#
# $C_3H_6Cl_2$ is propylene chloride (1,2-dichloropropane) (MW = 112.99).
#
#
# The species recovered after the reaction takes place for some time are listed as follows:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Based on the product distribution above, assuming that the feed consisted only of $Cl_2$ and $C_3H_6$, calculate the following:
#
# a. How much $Cl_2$ and $C_3H_6$ were fed to the reactor in gram moles?
#
# b. What was the limiting reactant?
#
# c. What was the excess reactant?
#
# d. What was the fraction conversion of $C_3H_6$ to $C_3H_5Cl$ and $C_3H_6Cl_2$?
#
# e. What was the selectivity of $C_3H_5Cl$ relative to $C_3H_6Cl_2$?
#
# f. What was the yield of $C_3H_5Cl$ expressed in grams of $C_3H_5Cl$ to the grams of $C_3H_6$ fed to the reactor?
#
# g. What was the extent of reaction of Reactions (1) and (2)?

# %% [markdown]
# **Solution**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# a. $Cl_2$ fed to reactor:
#
# Reaction (1):
# ![image.png](attachment:image.png)

# %% [markdown]
# Reaction (2):
# ![image.png](attachment:image.png)

# %% [markdown]
# similarly, 651.0 g mol of $C_3H_6$ exist unreacted in the product, 651.0 + 29.1 = 680.1 g mol of $C_3H_6$ were fed to the reactor.

# %% [markdown]
# b. and c.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Thus, $C_3H_6$ was the excess reactant and $Cl_2$ the limiting reactant.

# %% [markdown]
# d. The conversion of $C_3H_6$ to $C_3H_5Cl$ and $C_3H_6Cl_2$:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# e. The selectivity:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# f. The yield:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# g.
#
# Because $C_3H_5Cl$ is produced only by the first reaction, the extent of reaction of the first
# reaction is:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Because $C_3H_6Cl_2$ is produced only by the second reaction, the extent of reaction of the second
# reaction is:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5.3 Species Mole Balances

# %% [markdown]
# ### 5.3.1 Processes Involving a Single Reaction

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - The rate of change is written in moles because the generation and consumption terms are more conveniently represented in terms of moles because reactions are usually written in terms of molar ratios

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$NH_3: 6 – 0 = 6\text{ g mol (product generated)}$$
#
# $$H_2: 9 – 18 = –9\text{ g mol (reactant consumed)}$$
#
# $$N_2: 12 – 15 = –3\text{ g mol (reactant consumed)}$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For the $NH_3$ reaction:
# $$ν_{NH_3} = 2$$
#
# $$ν_{H_2} = –3$$
#
# $$ν_{N_2} = –1$$

# %% [markdown]
# $$\zeta=\frac{n_{NH_3}^{out}-n_{NH_3}^{in}}{v_{NH_3}}=\frac{6-0}{2}=3$$
#
# $$\zeta=\frac{n_{H_2}^{out}-n_{H_2}^{in}}{v_{H_2}}=\frac{9-18}{-3}=3$$
#
# $$\zeta=\frac{n_{N_2}^{out}-n_{N_2}^{in}}{v_{N_2}}=\frac{12-15}{-1}=3$$

# %% [markdown]
# - You can conclude for the case of a single chemical reaction that the specification of the extent of
# reaction provides one independent quantity that will determine all of the values of the generation and consumption terms for the various species in the reaction.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - The term $ν_i$ξ corresponds to the moles of species i generated or consumed

# %% [markdown]
# - In general you can write one material balance equation for each species present in the system.

# %% [markdown]
# - For a species that does not react, $ν_i$ = 0

# %% [markdown]
# **Frequently Asked Questions**

# %% [markdown]
# 1. Does it make any difference how the chemical reaction equation is written as long as the equation is balanced? No.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# calculate $\zeta$ for $NH_3$:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The material balance for $NH_3$ is:
# $$6 – 0 = (–1)(–6) = 6$$

# %% [markdown]
# calculate ξ for $H_2$, what result do you get?

# %% [markdown]
# - The product $ν_i$ξ, which is used in each species material balance, remains unchanged regardless of the size of the stoichiometric coefficients in a chemical reaction equation.

# %% [markdown]
# 2. What does the negative sign in front of ξ mean? The negative sign signifies that the chemical
# reaction equation was written to represent a direction that is the reverse of the one in which the reaction actually proceeds.

# %% [markdown]
# Are species balances always independent? Almost always.

# %% [markdown]
# - An example of a nonindependent set of species balances occurs for the decomposition of NH3 given
# one piece of information, namely, that 1 mole of $NH_3$ decomposes completely, the products of the reaction would be 3/2 $H_2$ and 1/2 $N_2$, and the $H_2$ and $N_2$ mole balances will not be independent because their ratio would always be 3 to 1.

# %% [markdown]
# - Would partial decomposition of the 1 mole of $NH_3$ lead to the same conclusion?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# where $f$ is the factor of conversion

# %% [markdown]
# **Example 5.3.1.1**: The chlorination of methane occurs by the following reaction:
#
# $$CH_4 + Cl_2 → CH_3Cl + HCl$$
#
# You are asked to determine the product composition if the conversion of the limiting reactant is
# 67%, and the feed composition in mole percent is 40% $CH_4$, 50% $Cl_2$, and 10% $N_2$.

# %% [markdown]
# **Solution**:
#
# Basis: 100 gmole feed

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Determine the limiting reactant:

# %% [markdown]
# $$\zeta^{max}(CH_4)=\frac{n_i-n_{io}}{v_i}=\frac{0-40}{-1}=40$$
#
# $$\zeta^{max}(Cl_2)=\frac{n_i-n_{io}}{v_i}=\frac{0-50}{-1}=50$$

# %% [markdown]
# Therefore, $CH_4$ is the limiting reactant. You can now calculate the extent of reaction using the
# specified conversion:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Number of variables: 11
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Known variables: $n_{CH_4}^{in}$,$n_{Cl_2}^{in}$,$n_{N_2}^{in}$, F and $\zeta$

# %% [markdown]
# Unknown variables: $n_{CH_4}^{out}$,$n_{Cl_2}^{out}$,$n_{N_2}^{out}$,$n_{HCl}^{out}$,$n_{Cl_2}^{out}$,$n_{CH_3Cl}^{out}$, and P

# %% [markdown]
# Number of independent equations needed: 6

# %% [markdown]
# Species material balances: 5 $CH_4$, $Cl_2$, $HCl$, $CH_3Cl$, $N2$

# %% [markdown]
# Implicit equation:1
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5.3.2. Processes Involving Multiple Reactions

# %% [markdown]
# - include in the species material balances only the ξs associated with a set of independent chemical reactions called the minimal set.

# %% [markdown]
# $$C + O_2 → CO_2$$
# $$C + ½O_2 → CO$$
# $$CO + ½O_2 → CO_2$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# where,
#
# $ν_{ij}$ is the stoichiometric coefficient of species i in reaction j in the minimal reaction set
#
# $ξ_j$ is the extent of reaction for the jth reaction in which component i is present in the minimal set.
#
# R is the number of independent chemical reaction equations (the size of the minimal set)

# %% [markdown]
# The total moles exiting the reactor:
#
# ![image.png](attachment:image.png)

# %% [markdown]
#  N : the total moles exiting the reactor.
#
#  S: the number of species in the system.

# %% [markdown]
# **Example 5.3.2.1**: Formaldehyde ($CH_2O$) is produced industrially by the catalytic oxidation of methanol ($CH_3OH$) by the following reaction:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Unfortunately, under the conditions used to produce formaldehyde at a profitable rate, a significant
# portion of the formaldehyde can react with oxygen to produce CO and $H_2O$:
#
# ![image.png](attachment:image.png)
#
# Assume that methanol and twice the stoichiometric amount of air needed for complete oxidation of
# the $CH_3OH$ are fed to the reactor, that 90% conversion of the methanol results, and that a 75%
# yield of formaldehyde occurs (based on the theoretical production of $CH_2O$ by Reaction (1)).
# Determine the composition of the product gas leaving the reactor.

# %% [markdown]
# **Solution**:
#
# Basis: 1 g mole $CH3OH$:
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$ξ_2 = (0.90 – 0.75) = 0.15 \text{ g mol reacting}$$

# %% [markdown]
# required amount of $O_2$:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Number of variables: 11
#
# ![image.png](attachment:image.png)

# %% [markdown]
# known variables:
# $$ F, A, \zeta_1, \zeta_2$$

# %% [markdown]
# Number of unknowns: 11 – 4 = 7

# %% [markdown]
# Number of independent equations needed: 11 – 4 = 7; here are 7 to select:

# %% [markdown]
# Species material balances: 6

# %% [markdown]
# $$CH_3OH, O_2, N_2, CH_2O, H_2O, CO$$

# %% [markdown]
# Implicit equation: 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Species material balances:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# $$y_{CH_3OH} = 1.6%$$
#
# $$y_{O_2} = 7.6%$$
#
# $$y_{N_2} = 59.8%$$
#
# $$y_{CH_2O} = 11.9%$$
#
# $$y_{H_2O} = 16.7%$$
#
# $$y_{CO} = 2.4%$$

# %% [markdown]
# **Example 5.3.2.2**: A bioreactor is a vessel in which biological reactions are carried out involving enzymes, microorganisms, and/or animal and plant cells. In the anaerobic (in the absence of oxygen)
# fermentation of grain, the yeast Saccharomyces cerevisiae digests glucose ($C_6H_{12}O_6$) from plants to form the products ethanol ($C_2H_5OH$) and propenoic acid ($C_2H_3CO_2H$) by the following overall reactions:
#
# Reaction 1: $$C_6H_{12}O_6 → 2C_2H_5OH + 2CO_2$$
# Reaction 2: $$C_6H_{12}O_6 → 2C_2H_3CO_2H + 2H_2O$$
#
# In a process, a tank is initially charged with 4000 kg of a 12% solution of glucose in water. After
# fermentation, 120 kg of $CO_2$ have been produced and 90 kg of unreacted glucose remain in the
# broth. What are the weight (mass) percents of ethanol and propenoic acid in the broth at the end of
# the fermentation process? Assume that none of the glucose is retained by the microorganisms.

# %% [markdown]
# **Solution**:
# Basis: 4000 kg of feed.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# F = 195.3+2.665 = 198 gmol

# %% [markdown]
# Number of variables: 9

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Known variables:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# You can make five species balances:
#
# $$H_2O, C_2H_{12}O_6, C_2H_5OH, C_2H_3CO_2H, CO_2$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $ξ_1$ = 1.364 kg mol reacting
#
# $ξ_2$ = 0.801 kg mol reacting

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The total mass of 3977 kg is close enough to 4000 kg of feed to validate the results of the
# calculations.

# %% [markdown]
# ## 5.4 Element Material Balances

# %% [markdown]
# - Elements are neither generated nor consumed.

# %% [markdown]
# $$In = Out$$

# %% [markdown]
# **Example 5.4.1**

# %% [markdown]
# $$NH_3 → N_2 + 3H_2$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Basis: 100 mole $NH_3$

# %% [markdown]
# N element balance:
#
# $$ 100\text{ mole }N = 2P(0.17)\text{ mole N} +P(0.33)\text{ mole N}=0.67 P\text{ mole N}$$

# %% [markdown]
# $$P=\frac{100}{0.67}=149\text{ moles}$$

# %% [markdown]
# **Example 5.4.2**: Barite (entirely composed of $BaSO_4$) is fused (reacted in the solid state) in a crucible with coke (composed of 94.0% C and 6.0% ash). The ash does not react. The final fusion mass of 193.7 g is removed from the crucible, analyzed, and found to have the following composition:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The gas evolved from the crucible does not smell, indicating the absence of sulfur dioxide, and contains 1.13 mole O per 1 mole C. What was the mass ratio of $BaSO_4$ to C (excluding the ash) in the reactants put into the crucible?

# %% [markdown]
# **Solution**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Basis: 100 g of P

# %% [markdown]
# |component|mass| MW  |gmol|
# |---------|----|-----|------|
# |$BaSO_4$ |11.1|233.3|0.0477|
# |$BaS$    |72.8|169.3|0.431 |
# |$C$      |13.9|12.0 |1.16  |
# |Ash      |2.2 | -   |  -   |

# %% [markdown]
# S mole balance:
#
# $$F(1)=0.0477+0.431=0.479$$
#
# $$F=0.479$$

# %% [markdown]
# O mole Balance:
#
# $$(0.479)(4)=(0.0477)(4)+G(\frac{1.13}{2.13})$$

# %% [markdown]
# $$G=3.52 \text{ mole}$$

# %% [markdown]
# C mole balance:
#
# $$\frac{C(0.94)}{12}=1.16+(3.52)(\frac{1}{2.13})$$
#
# $$C=35.9\text{ g C}$$

# %% [markdown]
# $$\frac{m_{BaSO_4}}{m_C}=\frac{(0.479)(233.3)}{(35.9}=3.11$$

# %% [markdown]
# **Example 5.4.3**:
#
# Hydrocracking is an important refinery process for converting low-valued heavy hydrocarbons to
# more valuable lower-molecular-weight hydrocarbons by exposing the feed to a zeolite catalyst at
# high temperature and pressure in the presence of hydrogen. Researchers study the hydrocracking of
# pure components, such as octane ($C_8H_{18}$), to understand the behavior of cracking reactions. In one such experiment, the cracked products had the following composition in mole percent: 19.5%
# C3H8, 59.4% $C_4H_{10}$, and 21.1% $C_5H_{12}$. You are asked to determine the molar ratio of hydrogen consumed to octane reacted for this experiment.

# %% [markdown]
# **Solution**:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Solution**:

# %% [markdown]
# Basis: 100 mole of product

# %% [markdown]
# C mole balance:

# %% [markdown]
# $$(19.5)(3)+(59.4)(4)+(21.1)(5)=(8)(F)$$
# $$F=50.2 \text{ mole of octane}$$

# %% [markdown]
# H balance:
#
# $$(50.2)(18)+2G=(19.5)(8)+(59.4)(10)+(21.1)(12)$$
#
# $$G=49.8 \text{ mole of Hydrogen}$$

# %% [markdown]
# $$\frac{H_2\text{ consumed}}{C_8H_{18}\text{ reacted}}=\frac{49.8}{50.2}=0.992$$

# %% [markdown]
# ## 5.5 Material Balances for Combustion Systems

# %% [markdown]
# **Combustion** is the reaction of oxygen with materials containing hydrogen, carbon, and sulfur, and the associated release of heat and the generation of product gases
# such as $H_2O$, $CO_2$, CO, and SO.

# %% [markdown]
# - combustion of coal, heating oil, and natural gas used to generate electricity in utility power stations.
# - combustion of gasoline or diesel fuel in cars and trucks engines.

# %% [markdown]
# - Most combustion processes use air as the source of oxygen. You can assume that air contains 79% $N_2$ and 21% $O_2$

# %% [markdown]
# - small amount of $N_2$ oxidizes to NO and $NO_2$, gases called $NO_x$, a pollutant, the amount is so small that we treat $N_2$ as a nonreacting component of air and fuel.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Pollutants resulting from combustion of natural gas vary with the air-fuel ratio and the temperature of combustion.

# %% [markdown]
# - The amount of hydrocarbons and CO increases with deficient air.

# %% [markdown]
# - Efficiency goes down with too much excess air, but so does the $NO_x$.

# %% [markdown]
# - (1) represents the optimal air-fuel ratio (no CO or unburned hydrocarbons).

# %% [markdown]
# - (2) represents inefficient combustion (excess air has to be heated).

# %% [markdown]
# - (3) represents unsatisfactory combustion (because not all of the fuel is burned and the unburned products are released to the atmosphere.

# %% [markdown]
# - **Flue or stack gas**: All of the gases resulting from a combustion process including the water vapor, sometimes known as a wet basis.

# %% [markdown]
# -  **Orsat analysis, or dry basis**: All of the gases resulting from a combustion process not including the water vapor. (Orsat analysis refers to a type of gas analysis apparatus in which the volumes of the respective gases are measured over and in equilibrium with water; hence each component
# is saturated with water vapor.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - **Complete combustion**: The complete reaction of the fuel producing $CO_2$ and $H_2O$.

# %% [markdown]
# - **Partial combustion**: The combustion of the fuel producing at least some CO from the carbon source. Because CO itself can react with oxygen, the production of CO in a combustion process does not produce as much energy as would be the case if only $CO_2$ were produced.

# %% [markdown]
# - **Theoretical air (or theoretical oxygen)**: The amount of air (or oxygen) required to be brought
# into the process for complete combustion. Sometimes this quantity is called the required air (or oxygen).

# %% [markdown]
# - **Excess air (or excess oxygen)**: is the amount of air (or oxygen) in excess of the theoretical air required for complete combustion.

# %% [markdown]
# - The calculated amount of excess air does not depend on how much material is actually burned but what could be burned if complete reaction of the material occurred. Even if only partial combustion takes place, as, for example, C burning to both CO and $CO_2$, the excess air (or oxygen) is computed as if the process of combustion produced only $CO_2$.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Example 5.5.1** Fuels for motor vehicles other than gasoline are being evaluated because they generate lower levels of pollutants than does gasoline. Compressed propane has been suggested as a source of power for vehicles. Suppose that in a test 20 kg of $C_3H_8$ is burned with 400 kg of air to produce 44 kg of $CO_2$ and 12 kg of CO. What was the percent excess air?

# %% [markdown]
# **Solution**

# %% [markdown]
# $$C_3H_8 + 5O_2 → 3CO_2 + 4H_2O$$

# %% [markdown]
# Basis: 20 kg of propane

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Oxygen entering the system:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The percentage excess air is
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Example 5.5.2**: suppose that a gas containing 80% $C_2H_6$ and 20% $O_2$ is burned in an engine with 200% excess air. Eighty percent of the ethane goes to $CO_2$, 10% goes
# to CO, and 10% remains unburned. What is the amount of the excess air per 100 moles of the $C_2H_6$?

# %% [markdown]
# **Solution**

# %% [markdown]
# - First, you can ignore the information about the CO and the unburned ethane because the basis of the
# calculation of excess air is complete combustion of the $C_2H_6$.

# %% [markdown]
# - Second, the oxygen in the fuel cannot be ignored.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 80 moles of $C_2H_6$ require 3.5(80) = 280 moles of $O_2$ for complete combustion>

# %% [markdown]
# The gas contains 20 moles of $O_2$, so only 280 – 20 = 260 moles of $O_2$ are needed in the entering air for complete combustion.

# %% [markdown]
# The calculation of the 200% excess $O_2$ (air) is based on 260, not 280, moles of $O_2$:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Example 5.5.3**: “A Fuel Cell in Every Car” is the headline of an article in Chemical and Engineering News (March 5, 2001, p. 19). In essence, a fuel cell is an open system into which fuel and air are fed, and out of which come electricity and waste products.  A sketch of a fuel cell in which a continuous flow of methane ($CH_4$) and air ($O_2$ plus $N_2$) produces electricity plus $CO_2$ and $H_2O$ shown below. Special membranes and catalysts are needed to promote the oxidation of the $CH_4$.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Calculate the composition of the products in P?

# %% [markdown]
# **Solution**:

# %% [markdown]
# Can you assume that a complete reaction occurs?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$CH_4 + 2O_2 → CO_2 + 2H_2O$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Known variables: F, A, $n_{O_2}^A$,$n_{N_2}^A$

# %% [markdown]
# species balances: $$CH_4, O_2, N_2, CO_2, H_2O$$

# %% [markdown]
# Implicit equation for P: ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Tthe mole percentage composition of P:
#
# $y_{O_2} = 1.5\%$
#
# $y_{N_2} = 72.1\%$
#
# $y_{CO_2} = 8.8\%$
#
# $y_{H_2O} = 17.6\%$

# %% [markdown]
# **Example 5.5.4**: A local utility burns coal having the following composition on a dry basis. (Note that the coal analysis below is a convenient one for our calculations but is not necessarily the only type of analysis that is reported for coal. Some analyses contain much less information about each
# element.)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The average Orsat analysis of the gas from the stack during a 24 hr test was

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Moisture ($H_2O$) in the fuel was 3.90%, and the air on the average contained 0.0048 lb H$_2$O/lb dry
# air. The refuse showed 14.0% unburned coal, with the remainder being ash. The unburned coal in
# the refuse can be assumed to be of the same composition as the coal that serves as fuel.
# What is the percent excess air used for this process as shown in the figure below?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Solution**:

# %% [markdown]
# Basis: F = 100 lb

# %% [markdown]
# Ash material balance:
#
# $$7.36 = 0.86R ⇒ R = 8.56 lb$$

# %% [markdown]
# Amount of coal combusted = 100. – 0.14 R = 98.8 lb

# %% [markdown]
# mole balance for C and S:
# ![image.png](attachment:image.png)

# %% [markdown]
# Solving for P yields P = 44.54 lb mol

# %% [markdown]
# nitrogen balance:
# ![image.png](attachment:image.png)

# %% [markdown]
# Solving yields A = 45.39 lb mol

# %%
45.39*.21
# Out:
# 9.5319

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
