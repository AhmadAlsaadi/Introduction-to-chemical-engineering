# %% [markdown]
# # <center> Chapter 7: Ideal and Real Gases

# %% [markdown]
# ## Objecitves

# %% [markdown]
# - Understand the conditions under which the ideal gas law applies, and conditions at which real gas relations must be used.

# %% [markdown]
# - Remember that the values of p and T used in relations to determine gas properties are
# absolute, not relative, values

# %% [markdown]
# - Use partial pressure in calculations involving multicomponent ideal gases.

# %% [markdown]
# - Solve material balances involving ideal or real gases.

# %% [markdown]
# **property** any measurable characteristic of a substance, such as pressure, volume, or
# temperature, or a characteristic that can be calculated or deduced, such as internal energy

# %% [markdown]
# The **state** of a system gives the condition of a system as specified by its properties.

# %% [markdown]
# sources of compounds and mixtures properties:
#  1. Experimental data
#  2. Table (developed from experimental data or theory)
#  3. Graphs
#  4. Equations

# %% [markdown]
# The absence of experimental data force us have to estimate (predict)
# properties based on empirical correlations or graphs.

# %% [markdown]
# **A phase** is defined as a
# completely homogeneous and uniform state of matter

# %% [markdown]
# ## 7.1 Ideal Gases

# %% [markdown]
# ### 7.1.1 Ideal gas equation

# %% [markdown]
# The most famous and widely used equation that relates p, V, n, and T for a gas is the **ideal gas law**:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# where p is the **absolute pressure** of the gas.
#
# $V$ is the total volume occupied by the gas.
#
# $n$ is the number of moles of the gas.
#
# $R$ is the ideal (universal) gas constant in appropriate units.
#
# $T$ is the **absolute temperature** of the gas.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('WhP6zJbSxec', width=800, height=400)

# %%
from IPython.display import HTML
HTML('<iframe width="663px" height="414px" frameborder="no" scrolling="no" allowfullscreen="true" webkitallowfullscreen="true" mozallowfullscreen="true" src="https://lab.concord.org/embeddable.html#interactives/sam/gas-laws/7-why-did-the-can-collapse.json"></iframe>')
# Out:
# <iframe width="663px" height="414px" frameborder="no" scrolling="no" allowfullscreen="true" webkitallowfullscreen="true" mozallowfullscreen="true" src="https://lab.concord.org/embeddable.html#interactives/sam/gas-laws/7-why-did-the-can-collapse.json"></iframe>

# %%
from IPython.display import HTML
HTML('<iframe width="663px" height="549px" frameborder="no" scrolling="no" allowfullscreen="true" webkitallowfullscreen="true" mozallowfullscreen="true" src="https://lab.concord.org/embeddable.html#interactives/sam/gas-laws/5-temperature-pressure-relationship.json"></iframe>')
# Out:
# <iframe width="663px" height="549px" frameborder="no" scrolling="no" allowfullscreen="true" webkitallowfullscreen="true" mozallowfullscreen="true" src="https://lab.concord.org/embeddable.html#interactives/sam/gas-laws/5-temperature-pressure-relationship.json"></iframe>

# %% [markdown]
# - Sometimes the ideal gas
# law is written as

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $\hat{V}$ is the specific molar volume (volume per mole, V/n)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The conditions for a gas to behave as predicted by the ideal gas law:

# %% [markdown]
# 1. The molecules do not occupy any space; they are infinitesimally small.
# 2. No attractive forces exist between the molecules so the molecules move completely
# independently of each other.
# 3. The gas molecules move in random, straight-line motion and the collisions between the
# molecules, and between the molecules and the walls of the container, are perfectly elastic.

# %% [markdown]
# As rule of thump:
# - Gases at low pressure and/or high temperature meet the ideal gas conditions.
# - Solids, liquids, and gases at high density—that is, high pressure and/or low temperature—do not.
# - From a practical viewpoint, within reasonable error, you can treat air, oxygen, nitrogen, hydrogen, carbon dioxide, methane, and even water vapor, under most of the ordinary conditions you encounter, as ideal gases.

# %% [markdown]
# **standard conditions** (S.C., or S.T.P., an acronym for
# “standard temperature and pressure”) of temperature and pressure have been specified for gases

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - You can insert the values at S.C. into the ideal gas equation to calculate R in any units you want.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Example 7.1.1** Calculate the volume, in cubic meters, occupied by 40 kg of $CO_2$ at standard conditions, assuming $CO_2$ acts as an ideal gas

# %% [markdown]
# **Example 7.1.2** Calculate the volume occupied by 88 lb of $CO_2$ at 15°C and a pressure of 32.2 ft of water.

# %% [markdown]
# **Solution**
#
# Basis: 40 kg of CO2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Example 7.1.2** Calculate the volume occupied by 88 lb of $CO_2$ at 15°C and a pressure of 32.2 ft of water.

# %% [markdown]
# **Solution**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# At S.C.:
#
# p = 33.91 ft $H_2O$
#
# $\hat{V}$= 359 $\frac{ft^3}{lb}\text{ mol }$
#
# T = 273 K

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Volumetric flow rate** of a gas, $\dot{V}$, such as in cubic meters or cubic feet per second,
# through a pipe, you divide the volume of the gas passing through the pipe in a time interval by the
# value of the time interval

# %% [markdown]
# $$\dot{V}=A\dot{v}$$

# %% [markdown]
# **velocity**, $\dot{v}$ of the flow, you divide the volumetric flow rate by
# the area, A, of the pipe

# %% [markdown]
# $$\dot{v}=\frac{\dot{V}}{A}$$

# %% [markdown]
# **Example 7.1.3** what is the density of N2 at 27°C and 100 kPa in SI units?

# %% [markdown]
# Basis: 1 $m^3$ of $N_2$ at 27°C and 100 kPa

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('SYBaJ01uBsI', width=800, height=400)

# %% [markdown]
# - The specific gravity of a gas is usually defined as the ratio of the density of the gas at a desired temperature and pressure to that of air (or any specified reference gas) at a certain temperature and pressure

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 7.1.2 Ideal Gas Mixtures

# %% [markdown]
# **The partial pressure**, pi, namely, the pressure that would be exerted by a
# single component in a gaseous mixture if it existed alone in the same volume as that occupied by the
# mixture and at the same temperature as the mixture

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# where $y_i$ is the mole fraction of component i

# %% [markdown]
# **Dalton’s law** of the summation of partial pressures:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('J7YRwU7IV8Q', width=800, height=400)

# %% [markdown]
# **Example 7.1.2.1** Few organisms are able to grow in solution using organic compounds that contain just one carbon
# atom such as methane or methanol. However, the bacterium Methylococcus capsulates can growunder aerobic conditions (in the presence of air) on C-1 carbon compounds. The resulting biomass
# is a good protein source that can be used directly as feed for domestic animals or fish.
# In one process the off-gas analyzes 14.0% CO2, 6.0% O2, and 80.0% N2. It is at 300°F and 765.0
# mm Hg pressure. Calculate the partial pressure of each component.

# %% [markdown]
# **Solution**
# Basis: 1.00 kg (or lb) mol of off-gas

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 7.1.3 Material Balances Involving Ideal Gases

# %% [markdown]
# **Example 7.1.3.1** To evaluate the use of renewable resources, an experiment was carried out with rice hulls. After
# pyrolysis, the product gas analyzed 6.4% CO2, 0.1% O2, 39% CO, 51.8% H2, 0.6% CH4, and 2.1%
# N2. It entered a combustion chamber at 90°F and a pressure of 35.0 in. Hg and was burned with
# 40% excess air (dry) at 70°F and an atmospheric pressure of 29.4 in. Hg; 10% of the CO remains.
# How many cubic feet of air were supplied per cubic foot of entering gas? How many cubic feet of
# product gas were produced per cubic foot of entering gas if the exit gas was at 29.4 in. Hg and
# 400°F?

# %% [markdown]
# **Solution**
#
# Basis: 100 lb mol of pyrolysis gas

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Total moles of air in are 244.9 + 65.1 = 310.0 lb mol.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $nN_2$ = 247
#
# $nCO_2$ = 42.1
#
# $nH_2O$ = 53.0
#
# $nO_2$ = 20.55

# %% [markdown]
# The total moles exiting calculated from the implicit equation sum to 366.6 mol

# %% [markdown]
# $$Tgas = 90 + 460 = 550°R → 306 K$$
# $$Tair = 70 + 460 = 530°R → 294 K$$
# $$Tproduct = 400 + 460 = 860°R → 478 K$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **ُExample 7.1.3.2** Gas at 15°C and 105 kPa is flowing through an irregular duct. To determine the rate of flow of the gas, $CO_2$ from a tank is steadily passed into the gas stream. The flowing gas, just before mixing
# with the $CO_2$, analyzes 1.2% $CO_2$ by volume. Downstream, after mixing, the flowing gas analyzes
# 3.4% $CO_2$ by volume. As the $CO_2$ that was injected exited the tank, it was passed through arotameter and found to flow at the rate of 0.0917 m3/min at 7°C and 131 kPa. What was the rate of
# flow of the entering gas in the duct in cubic meters per minute?

# %% [markdown]
# **Solution**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The gas analysis is in volume percent, which is the same as mole percent.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# F = 5.17 m3/min at 15°C and 105 kPa

# %% [markdown]
# ## 7.2 Real Gases: Equations of State

# %% [markdown]
# Gases whose properties cannot be represented by the ideal gas law are called **nonideal gases** or **real gases**.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('UABFOI1sb7A', width=800, height=400)

# %% [markdown]
# Real gas properties are predicted by equations called **equations of state**.

# %% [markdown]
# ### 7.2.1. Equations of State

# %% [markdown]
# - The simplest example of what is called an equation of state is the ideal gas law itself.

# %% [markdown]
# - Equations of state for nonideal gases can be just empirical relations selected to fit a data set, or they can be based on theory, or a combination of the two.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 7.2.2 The Critical State and Compressibility

# %% [markdown]
# The **critical state** (point) for the gas-liquid transition is the set of physical conditions at which the density and other properties of the liquid and vapor become identical.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('c_ZIzZxqVIE', width=800, height=400)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A **supercritical fluid** is a compound in a state above its critical point.

# %% [markdown]
# **Reduced variables** are the conditions of temperature, pressure, or specific volume normalized (divided) by their respective critical conditions, as follows:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In theory, the **law of corresponding states** indicates that any compound should have the same reduced volume at the same reduced temperature and reduced pressure so that a universal gas law might be

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Unfortunately Equation above does not universally make accurate predictions

# %% [markdown]
# - The concept of reduced variables nevertheless has been applied to prediction of real gas properties

# %% [markdown]
# - One common way is to modify the ideal gas law by inserting an adjustable coefficient z, the
# compressibility factor, a factor that compensates for the nonideality of the gas, and can be looked at as a measure of nonideality

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - The ideal gas law is turned into a real gas law called a **generalized
# equation of state**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - The acentric factor ω or Pitzer acentric factor indicates the degree of acentricity or nonsphericity of a molecule. For helium and argon, ω is equal to zero. For higher-molecular-weight hydrocarbons and for molecules with
# increased polarity, the value of ω increases.

# %% [markdown]
# ω is unique for each
# compound

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Tables in Appendix C list values of $z_0$ and $z_1$ as a function of $T_r$ and $P_r$

# %% [markdown]
# **Example 7.2.2.1** Calculate z via the Pitzer correlation, calculate the compressibility factor z for ethylene (C2H4) at 300 K and 3000 kPa.

# %% [markdown]
# **Solution**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Look up (using interpolation) $z_0$ (0.812) and $z_1$ (–0.01) as well as ω (0.089) from Appendix C or
# Table 7.3

# %% [markdown]
# $$z = 0.812 + (–0.01)(0.089) = 0.812$$

# %% [markdown]
# - A different way of predicting p,$\hat{V}$ , and T properties is the group contribution method which has been successful in estimating properties of pure components.
#
# This method is based on combining the contribution of each functional group of a compound. The key assumption is that a group such as $–CH_3$ or –OH behaves identically irrespective of the molecule in which it appears.
#
# This assumption is not quite true, so any group contribution method yields approximate values for gas properties.
#
# Probably the most widely used group contribution method is **UNIFAC**, which forms a part of many computer databases.
#
# **UNIQUAC** (Universal Quasichemical)  is equal to **UNIFAC** for mixtures of molecules and is widely used in the chemical industry in the modeling of nonideal systems (systems with strong interaction between the molecules).
