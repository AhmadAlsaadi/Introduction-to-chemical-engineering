# %% [markdown]
# # <center> Course Main Concepts </center>
#
# ## Chapter 2:
#
# - Unit conversion
#
# - Significant figures
#
# - Dimensional analysis
#
# - Choosing a basis
#
# - Density and specific gravity
#
# - Concentration
#
# - Pressure (absolute and relative)
#
# - Temperature (absolute and relative)
#
# - Flow rate
#
# - Mass and mole fractions.
#
# ## Chapter 3:
#
# - Concept of material balance
#
# - System types
#
# - System boundaries
#
# - Steady-state and unsteady state
#
# - Continuous semi-batch and batch processes
#
# - Material balance without reaction for single component
#
# - Material balance without reaction for multiple components
#
# - Translate problems in to sketch and labeling the sketch properly.
#
# - Explicit and implicit equations.
#
#
# ## Chapter 4:
#
# - Material balance without reaction
#
#     - Separation
#
#         - Liquid-Liquid extraction
#
#         - Distillation
#
#         - Membrane filtration
#
#         - Hemodialysis
#
#         - Drying
#
#         - Chromatographic Column
#
#     - Mixing
#
# ## Chapter 5:
#
# - Balance chemical reaction equation
#
# - Use of the Chemical Reaction Equation to Calculate the Mass of Reactants
# Given the Mass of Products
#
# - Application of Stoichiometry When More than One Reaction Occurs
#
# - Extent of Reaction, ξ
#
# - Limiting and Excess Reactants
#
# - Conversion and Degree of Completion
#
# - Selectivity
#
# - Yield
#
# - Species Mole Balances.
#
# - Element Material Balances
#
# - Material Balances for Combustion Systems
#
# - Orsat analysis, or dry basis
#
# - Flue or stack gas
#
# - Complete combustion
#
# - Partial combustion
#
# - Theoretical air or theoretical oxygen
#
# - Excess air or excess oxygen
#
# ## Chapter 6:
#
# - Flowsheet and block diagram
#
# - Mixer
#
# - Splitter
#
# - Subsystems
#
# - Sequential multi-unit systems
#
# - Overall and subsystem material balances.
#
# - Determine independent material balance equations
#
# - Use of Mole fraction and mass fraction in material balance equations.
#
# - Material Balances for Multiple Units in Which No Reaction Occurs
#
# - Material Balances for Multiple Units in Which a Reaction Occurs .
#
# - Solving material balance problem with recycle stream involving reaction or without reaction
#
# - The purpose of using recycle stream in a process
#
# - Overall all conversion
#
# - Single pass conversion.
#
# - Solving material balance with bypass and purge streams
#
# - The purpose of using bypass and purge stream in a process.
#
#
#
# ## Chapter 7:
#
# - Ideal gas law
#
#     - Forms of ideal gas law (PV=nRT, PVˆ=RT, ρ=MwPRT)
#
#     - The use of absolute pressure and temperature
#
#     - The standard conditions
#
#     - Assumption of ideal gas law
#
#     - At what conditions ideal gas law can be valid.
#
#     - Use of Standard Conditions to Calculate Volume from Mass.
#
#     - Application of the Ideal Gas Law to Calculate a Volume at nonstandard conditions.
#
#     - Specific gravity of a gas.
#
#     - Volumetric and velocity of a gas.
#
#     - Idea gas mixtures
#
#         - Dalton’s law (partial pressure)
#
#         - Calculation of the Partial Pressures of the Components in a Gas
#
#     - Use of ideal gas law in material balance.
#
#     - volume percent is the same as mole percent.
#
# - Real gas
#
#     - Conditions at which ideal gas law cannot be applied.
#
#     - Critical temperature
#
#     - Critical pressure
#
#     - Critical specific volume
#
#     - Equation of state
#
#         - <mark>Pros and cons</mark>
#
#         - <mark>Use of the RK Equation to Calculate pressure or specific volume.</mark>
#
#     - Supercritical fluid
#
#     - Reduced temperature
#
#     - Reduced pressure
#
#     - Reduced specific volume
#
#     - Compressibility factor z
#
#         - Graphical method
#
#         - Pitzer’s correlation method
#
#         - Use of the Compressibility Factor in Calculating a Specific Volume.
#
#         - <mark>Use of the Compressibility Factor in Calculating a Pressure</mark>
#
# - Real gas mixture
#
#     - Pseudoreduced variables
#
#     - Kay’s method
#
#     - Calculation of p-V-T Properties for a Real Gas Mixture.
#
#     - Solving material balances that has ideal or real gases in the process.

# %% [markdown]
# <mark> The highlighted items are not included in the final exam</mark>
